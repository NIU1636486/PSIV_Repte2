# %%
#import sys
#print(sys.version)

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\marcp\anaconda3\lib\site-packages (8.3.9)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (1.24.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\marcp\anaconda3\lib\site-packages (from ultralytics) (2.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marcp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marcp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\marcp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marcp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marcp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marcp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marcp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\marcp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\marcp\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\marcp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marcp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\marcp\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.3.9'

# %%
# Not training the model, just using pretrained model trained on COCO dataset. 
# Aquest dataset té som vehicles a part d'altres objectes.
#Fer servir aquest model per la detecció i després track i count
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

model=YOLO('yolov5n.pt')
# Out:
# PRO TIP  Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
#list of COCO dataset classes
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
#creant una instancia de tracker que ve de from tracker import*
tracker=Tracker()
count=0

# %%
#llegir el video
cap=cv2.VideoCapture('output2.mp4')

# %%
#VARIABLES PER GUARDAR COTXES UP I DOWN
down={}
up={}

counter_down=[]
counter_up=[]

# %%
import time
import numpy as np

# Inicialitzar el comptador de FPS
fps = 0
start_time = time.time()
pts = np.array([[359, 480],[186, 480] ,[8, 840], [446, 841]], np.int32)
# divide all values by 2
pts = pts // 2
pts = pts.reshape((-1, 1, 2))

# Bucle infinit per processar el vídeo frame a frame
while True:
    # Llegir un nou frame de la captura de vídeo
    ret, frame = cap.read()
    if not ret:  # Si no hi ha més frames, surt del bucle
        break
    count += 1

    # RESOLUCIÓ IMATGE ORIGINAL: 960X540
    # REDUIR RESOLUCIÓ a 270x480
    frame = cv2.resize(frame, (270, 480))
    original_frame = frame.copy()

    mask = np.zeros_like(frame, dtype=np.uint8)
    cv2.fillPoly(mask, [pts], (255, 255, 255))
    roi_frame = cv2.bitwise_and(original_frame, mask)
    
    # Saltar 1 de cada 2 frames per processar menys imatges
    if count % 4 != 0:
        fps += 1
        end_time = time.time()
        elapsed_time = end_time - start_time
        if elapsed_time > 0:
            # Calcular FPS actuals
            current_fps = fps / elapsed_time
            # Mostrar els FPS al frame
            cv2.putText(frame, f'FPS: {round(current_fps, 2)}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
            # Dibuixar la línia única al frame per detectar el moviment
            cv2.line(frame, (0, 400), (800, 400), (0, 0, 255), 3)  # línia vermella (única)
    

    results = model.predict(roi_frame)

    # Obtenir les dades de la bounding box i la confiança de la predicció
    a = results[0].boxes.data
    a = a.detach().cpu().numpy()
    px = pd.DataFrame(a).astype("float")

    # Filtrar només les bounding boxes de cotxes
    car_bboxes = []
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]  # Obtenir la classe de l'objecte detectat
        if 'car' in c:  # Si l'objecte és un cotxe, guardar la seva bounding box
            car_bboxes.append([x1, y1, x2, y2])

    # Proporcionar les coordenades de les bounding boxes al tracker
    bbox_id = tracker.update(car_bboxes)

    # Dibuixar les bounding boxes i els IDs al frame
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = int((x3 + x4) // 2)  # Coordenada central de la bounding box (x)
        cy = int((y3 + y4) // 2)  # Coordenada central de la bounding box (y)

        # Actualitzar comptadors de cotxes que baixen o pugen
        line_y = 400  # Coordenada y de la línia única
        offset = 7  # Margen d'error per la detecció de passos per la línia

        # Si el cotxe estava a la part superior i després passa a la part inferior, comptar com a baixada
        if cy < line_y - offset:  # Cotxe a la part superior de la línia
            down[id] = cy  # Guardar la y del cotxe quan està a la part superior
        if id in down:
            if cy > line_y + offset:  # Cotxe passa a la part inferior
                # Dibuixar un punt vermell al cotxe que baixa
                cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)  # punt vermell
                # Mostrar l'ID del cotxe al frame
                cv2.putText(frame, str(id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)
                counter_down.append(id)  # Afegir l'ID a la llista de cotxes que baixen

        # Si el cotxe estava a la part inferior i després passa a la part superior, comptar com a pujada
        if cy > line_y + offset:  # Cotxe a la part inferior de la línia
            up[id] = cy  # Guardar la y del cotxe quan està a la part inferior
        if id in up:
            if cy < line_y - offset:  # Cotxe passa a la part superior
                # Dibuixar un punt vermell al cotxe que puja
                cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)  # punt vermell
                # Mostrar l'ID del cotxe al frame
                cv2.putText(frame, str(id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)
                counter_up.append(id)  # Afegir l'ID a la llista de cotxes que pugen

    # Dibuixar la línia vermella al frame
    cv2.line(frame, (0, 400), (800, 400), (0, 0, 255), 3)  # línia vermella (única)

    # Mostrar el nombre de cotxes que han baixat i pujat
    downwards = len(set(counter_down))  # Comptar cotxes únics que han baixat
    upwards = len(set(counter_up))  # Comptar cotxes únics que han pujat

    # Imprimir els resultats
    print(f"Baixada: {downwards}")
    print(f"Pujada: {upwards}")

    # Càlcul de FPS (frames per segon)
    fps += 1
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time > 0:
        # Calcular i mostrar els FPS al frame
        current_fps = fps / elapsed_time
        cv2.putText(frame, f'FPS: {round(current_fps, 2)}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    # Mostrar el frame actualitzat
    cv2.imshow("frames", frame)
    cv2.imshow("roi", roi_frame)
    if cv2.waitKey(1) & 0xFF == 27:  # Sortir si es prem la tecla ESC
        break

# Alliberar la captura de vídeo i destruir totes les finestres
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 (no detections), 480.6ms
# Speed: 14.8ms preprocess, 480.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 773.4ms
# Speed: 10.4ms preprocess, 773.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 432.7ms
# Speed: 21.2ms preprocess, 432.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 book, 845.7ms
# Speed: 15.4ms preprocess, 845.7ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 472.4ms
# Speed: 21.2ms preprocess, 472.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 476.7ms
# Speed: 12.4ms preprocess, 476.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 507.5ms
# Speed: 25.3ms preprocess, 507.5ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 420.4ms
# Speed: 15.0ms preprocess, 420.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 347.5ms
# Speed: 12.0ms preprocess, 347.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 book, 305.4ms
# Speed: 10.4ms preprocess, 305.4ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 344.4ms
# Speed: 11.3ms preprocess, 344.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 413.7ms
# Speed: 10.0ms preprocess, 413.7ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 443.5ms
# Speed: 8.9ms preprocess, 443.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 422.3ms
# Speed: 14.2ms preprocess, 422.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 466.7ms
# Speed: 13.0ms preprocess, 466.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 3368.4ms
# Speed: 15.3ms preprocess, 3368.4ms inference, 68.7ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 9518.6ms
# Speed: 37.6ms preprocess, 9518.6ms inference, 9.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 6628.2ms
# Speed: 23.4ms preprocess, 6628.2ms inference, 14.6ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 3499.7ms
# Speed: 24.6ms preprocess, 3499.7ms inference, 12.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 4652.2ms
# Speed: 23.5ms preprocess, 4652.2ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 2065.3ms
# Speed: 37.1ms preprocess, 2065.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 632.8ms
# Speed: 20.1ms preprocess, 632.8ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 1954.6ms
# Speed: 22.8ms preprocess, 1954.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 684.0ms
# Speed: 17.3ms preprocess, 684.0ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 527.6ms
# Speed: 12.5ms preprocess, 527.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 2066.8ms
# Speed: 14.3ms preprocess, 2066.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 1088.6ms
# Speed: 25.5ms preprocess, 1088.6ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 1827.0ms
# Speed: 32.3ms preprocess, 1827.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 1396.8ms
# Speed: 39.3ms preprocess, 1396.8ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 2720.4ms
# Speed: 48.5ms preprocess, 2720.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 541.0ms
# Speed: 14.8ms preprocess, 541.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 559.2ms
# Speed: 21.7ms preprocess, 559.2ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 686.1ms
# Speed: 14.2ms preprocess, 686.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 544.2ms
# Speed: 13.6ms preprocess, 544.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 692.4ms
# Speed: 17.9ms preprocess, 692.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 508.1ms
# Speed: 16.1ms preprocess, 508.1ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 560.5ms
# Speed: 20.8ms preprocess, 560.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 614.6ms
# Speed: 15.0ms preprocess, 614.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 728.6ms
# Speed: 14.5ms preprocess, 728.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 514.0ms
# Speed: 15.0ms preprocess, 514.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 643.5ms
# Speed: 23.6ms preprocess, 643.5ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 578.7ms
# Speed: 15.1ms preprocess, 578.7ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 610.8ms
# Speed: 15.3ms preprocess, 610.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 595.8ms
# Speed: 15.3ms preprocess, 595.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 507.1ms
# Speed: 16.4ms preprocess, 507.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 495.0ms
# Speed: 22.5ms preprocess, 495.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections), 484.0ms
# Speed: 13.3ms preprocess, 484.0ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 (no detections),
ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 307.7ms
# Speed: 10.4ms preprocess, 307.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 279.6ms
# Speed: 9.4ms preprocess, 279.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 258.8ms
# Speed: 9.7ms preprocess, 258.8ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 256.7ms
# Speed: 8.6ms preprocess, 256.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 236.3ms
# Speed: 9.2ms preprocess, 236.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 219.2ms
# Speed: 11.3ms preprocess, 219.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 247.8ms
# Speed: 6.4ms preprocess, 247.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 212.8ms
# Speed: 6.8ms preprocess, 212.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 256.0ms
# Speed: 9.0ms preprocess, 256.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 312.3ms
# Speed: 7.0ms preprocess, 312.3ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 478.7ms
# Speed: 10.3ms preprocess, 478.7ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 777.6ms
# Speed: 5.0ms preprocess, 777.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 342.6ms
# Speed: 10.6ms preprocess, 342.6ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 340.9ms
# Speed: 11.2ms preprocess, 340.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 360.9ms
# Speed: 11.4ms preprocess, 360.9ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
#
# 0: 640x384 1 car, 357.2ms
# Speed: 12.3ms preprocess, 357.2ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 384)
# Baixada: 0
# Pujada: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 43
#      39         # Dibuixar la línia única al frame per detectar el moviment
#      40         cv2.line(frame, (0, 400), (800, 400), (0, 0, 255), 3)  # línia vermella (única)
# ---> 43 results = model.predict(roi_frame)
#      45 # Obtenir les dades de la bounding box i la confiança de la predicció
#      46 a = results[0].boxes.data
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\ultralytics\engine\model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:261, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     259 # Postprocess
#     260 with profilers[2]:
# --> 261     self.results = self.postprocess(preds, im, im0s)
#     262 self.run_callbacks("on_predict_postprocess_end")
#     264 # Visualize, save, write results
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\ultralytics\models\yolo\detect\predict.py:25, in DetectionPredictor.postprocess(self, preds, img, orig_imgs)
#      23 def postprocess(self, preds, img, orig_imgs):
#      24     """Post-processes predictions and returns a list of Results objects."""
# ---> 25     preds = ops.non_max_suppression(
#      26         preds,
#      27         self.args.conf,
#      28         self.args.iou,
#      29         agnostic=self.args.agnostic_nms,
#      30         max_det=self.args.max_det,
#      31         classes=self.args.classes,
#      32     )
#      34     if not isinstance(orig_imgs, list):  # input images are a torch.Tensor, not a list
#      35         orig_imgs = ops.convert_torch2numpy_batch(orig_imgs)
#
# File c:\Users\marcp\anaconda3\Lib\site-packages\ultralytics\utils\ops.py:244, in non_max_suppression(prediction, conf_thres, iou_thres, classes, agnostic, multi_label, labels, max_det, nc, max_time_img, max_nms, max_wh, in_place, rotated)
#     241     else:
#     242         prediction = torch.cat((xywh2xyxy(prediction[..., :4]), prediction[..., 4:]), dim=-1)  # xywh to xyxy
# --> 244 t = time.time()
#     245 output = [torch.zeros((0, 6 + nm), device=prediction.device)] * bs
#     246 for xi, x in enumerate(prediction):  # image index, image inference
#     247     # Apply constraints
#     248     # x[((x[:, 2:4] < min_wh) | (x[:, 2:4] > max_wh)).any(1), 4] = 0  # width-height
#
# KeyboardInterrupt:
